# %%
## the multiple varaiable  you can save it 


dict1={}

type(dict1)
# Out:
# dict

# %%
dict1 = {"name": "abbas", "age": "23"}

print(dict1["name"])
print(dict1["age"])
# Out:
# abbas
# 23

# %%
import pandas as pd

# %%
data = [
    {"from": "to", "cost": 0},
    {"a": "b", "cost": 10},
    {"a": "d", "cost": 14},
    {"a": "c", "cost": 30},
]
# Out:
#   Cell In[2], line 1
#     data=[{"from":"to":"cost"},
#                       ^
# SyntaxError: invalid syntax
