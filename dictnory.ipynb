# %%
## the multiple varaiable  you can save it 


dict1={}

type(dict1)
# Out:
# dict

# %%
dict1 = {"name": "abbas", "age": "23"}

print(dict1["name"])
print(dict1["age"])
# Out:
# abbas
# 23

# %%
import pandas as pd

# %%
data = [
    {"from": "to", "cost": 0},
    {"a": "b", "cost": 10},
    {"a": "d", "cost": 14},
    {"a": "c", "cost": 30},
]


df_graph=pd.DataFrame(data)

# %%
df_graph
# Out:
#   from  cost    a
# 0   to     0  NaN
# 1  NaN    10    b
# 2  NaN    14    d
# 3  NaN    30    c

# %%
data.append({"c": "f", "cost": 50})

# %%
data
# Out:
# [{'from': 'to', 'cost': 0},
#  {'a': 'b', 'cost': 10},
#  {'a': 'd', 'cost': 14},
#  {'a': 'c', 'cost': 30},
#  {'c': 'f', 'cost': 50}]

# %%
print(data.pop())
# Out:
# {'c': 'f', 'cost': 50}

# %%
data
# Out:
# [{'from': 'to', 'cost': 0},
#  {'a': 'b', 'cost': 10},
#  {'a': 'd', 'cost': 14},
#  {'a': 'c', 'cost': 30}]

# %%
data = {"banana": 3, "apple": 5, "cherry": 1}

sorteddic=dict(sorted(data.items()))

print(sorteddic)
# Out:
# {'apple': 5, 'banana': 3, 'cherry': 1}

# %%
new_data=data.copy()


print(new_data)
# Out:
# {'banana': 3, 'apple': 5, 'cherry': 1}

# %%
#mix opreations 


student_data={f"id_{i}":(f"student_{i}",50+(i%50))for i in range(1,51)}

student_data
# Out:
# {'id_1': ('student_1', 51),
#  'id_2': ('student_2', 52),
#  'id_3': ('student_3', 53),
#  'id_4': ('student_4', 54),
#  'id_5': ('student_5', 55),
#  'id_6': ('student_6', 56),
#  'id_7': ('student_7', 57),
#  'id_8': ('student_8', 58),
#  'id_9': ('student_9', 59),
#  'id_10': ('student_10', 60),
#  'id_11': ('student_11', 61),
#  'id_12': ('student_12', 62),
#  'id_13': ('student_13', 63),
#  'id_14': ('student_14', 64),
#  'id_15': ('student_15', 65),
#  'id_16': ('student_16', 66),
#  'id_17': ('student_17', 67),
#  'id_18': ('student_18', 68),
#  'id_19': ('student_19', 69),
#  'id_20': ('student_20', 70),
#  'id_21': ('student_21', 71),
#  'id_22': ('student_22', 72),
#  'id_23': ('student_23', 73),
#  'id_24': ('student_24', 74),
#  'id_25': ('student_25', 75),
#  'id_26': ('student_26', 76),
#  'id_27': ('student_27', 77),
#  'id_28': ('student_28', 78),
#  'id_29': ('student_29', 79),
#  'id_30': ('student_30', 80),
#  'id_31': ('student_31', 81),
# ...

# %%
# Our sample dataset: A single employee record
employee = {
    "id": 101,
    "name": "Sarah Connor",
    "department": "Cybernetics",
    "salary": 75000,
    "skills": ["Python", "Security", "AI"]
}

for key,val in employee.items():
    

    print (key,val)
# Out:
# id 101
# name Sarah Connor
# department Cybernetics
# salary 75000
# skills ['Python', 'Security', 'AI']
