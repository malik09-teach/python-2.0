# %% [markdown]
# CONDITIONS

# %% [markdown]
# # SINGLE IF ELSE

# %%
#EVEN ODD NUMBERS 

num=int(input("enter number"))

if num%2==0:
    print("number is even")
else :
    print ("number is odd")
# Out:
# number is odd

# %% [markdown]
# # multiple if else and elif

# %%
# grade system 
  
marksObtain = int (input ( "enter marks of student "))  

if marksObtain >=85:
    print ("grade A")
elif marksObtain >= 70:
    print ("grade B")   

elif marksObtain >= 55:
    print ("grade C")

elif marksObtain >= 40:
    print ("grade D")

elif marksObtain >= 33:
    print ("grade E")

elif marksObtain < 33:
    print ("fail")


else :
    print ( " invalid entery ")
# Out:
# grade C

# %% [markdown]
# # nested if else

# %%
# double authentications 
passcode =str(input( "enter password "))

if passcode == "malik":
    print ("password is valid")
    otp=int(input("putt income otp"))
    if otp==123:
        print("password and otp is valid ")
        print ("\n \n \n")
        print ("welcome to the system ")
    else:
        print ("enter valid otp")

else:
    print ("enter valid password ")
# Out:
# password is valid
# enter valid otp

# %% [markdown]
# OPREATORS

# %%
# AND 

# frequency range checking

range=int(input ("enter range of frequency")) 

if range > 400 and range <450:
    print ("color is blue") 
elif range > 450 and range <500:
    print ("color is voilet")
elif range > 500 and range <550:
      print ("color is green ")
elif range > 550 and range <600:
    print ("color is orange")
elif range > 600 and range <650:
      print ("color is flame ")
elif range > 650 and range <700:    
     print ("color is red") 
else:
     print ("infrad zone ")
# Out:
# color is orange

# %%
# or 
# scan latter 

latter = str(input("Enter a letter: "))

if len(latter) == 1:
    
    char_code = ord(latter)

    if (65 <= char_code <= 90) or (97 <= char_code <= 122):
        print("You entered a letter")
    else:
        print("You entered something else")
else:
    print("Please enter only one character")
# Out:
# You entered a letter

# %%
# not 
# not to concern to some phenomenea 
# let take the value or sum variable 

x=input ("enter take somthing from keyboard:")


if  not x.isalpha():
    print ( "not the the latter ")

else :
    print ("u hit latter  ",x)
# Out:
# u hit latter   A
