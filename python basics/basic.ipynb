# %% [markdown]
# BASIC OPREATIONS IN PYTHON

# %% [markdown]
# ## PRINTING

# %%
print ( "hello world")
# Out:
# hello world

# %% [markdown]
# #  VARIABLE

# %%
#VARIABLE 
INRERGERX= 10 
WORDSX="ABBAS"
STRINGX= "HELLO MR ABBAS KHAN " 

print (INRERGERX, "\n")
print (WORDSX, "\n")
print (STRINGX, "\n")
# Out:
# 10
#
# ABBAS
#
# HELLO MR ABBAS KHAN

# %% [markdown]
# # OPREATION ON INTEGER

# %%
x1=10
x2=20 

print("addition x1+x2:",x1+x2)
print("subtraction x1-x2:",x1-x2)
print("multiplication x1*x2:",x1*x2)
print("division x1/x2:",x1/x2)
# Out:
# addition x1+x2: 30
# subtraction x1-x2: -10
# multiplication x1*x2: 200
# division x1/x2: 0.5

# %% [markdown]
# # get input from the user

# %%
x1=int(input( "eneter number x1:"))
x2=int (input (" enter number x2:"))

print("x1 entered:",x1)
print("x2 entered:",x2)



print("addition x1+x2:",x1+x2)
print("subtraction x1-x2:",x1-x2)
print("multiplication x1*x2:",x1*x2)
print("division x1/x2:",x1/x2)
# Out:
# x1 entered: 11
# x2 entered: 2
# addition x1+x2: 13
# subtraction x1-x2: 9
# multiplication x1*x2: 22
# division x1/x2: 5.5

# %% [markdown]
# # conditions

# %%
x1=int(input( "eneter number x1:"))


if x1>0:
    print ("postive number:",x1)
elif x1<0:
    print ("negitive number:",x1)
else :
    print("number is zero:",x1)
# Out:
# negitive number: -1

# %% [markdown]
# # calculator

# %%
x1=int(input( "eneter number x1:"))
x2=int (input (" enter number x2:"))

opt=str(input(" enter opreator (+,-,*,/)"))

res=0



match  opt:   
    case "+":
        res=x1+x2
        print("result ", x1, "+", x2,":",res)      
    case "-":
        res=x1-x2
        print("result ", x1, "-", x2,":",res)
    case "*":
        res=x1*x2
        print("result ", x1, "*", x2,":",res)
    case "/":
         res=x1/2
         print("result ", x1, "/", x2,":",res)
# Out:
# result  11 - 22 : -11
