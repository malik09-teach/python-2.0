# %% [markdown]
# LOOPS

# %% [markdown]
# # FOR LOOP

# %%
# the fix size and we want to the itreate it 
for i in range(5):# basic syntax in the python 

    print (i) # print just the number 
# the i=0 is basically in the for loop  i is kept 0 in the whole itreation unless if you cant change it in the range fun 
# and in function of the range goes to number-1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
 # loop b/w the range 
# in the range function the diff parameter can pass to controll the flow of the loop 
# in simple (for i in range (start ,end)

for i in range (5,10):
    print(i)
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
# their is step up parameter also availble in the loop in which the increament the number by steps up to step 
for i  in range (0 ,11,2):
    print (i)
# in every counter the number itreating after 2 digit
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# NESTED FOR LOOP

# %%
# let take multiplication 
j=1
i=1


l1=[1,2,3,4,5,6,7]
l2=[1,2,3,4,5,6,7]

for i in l1:
    for j in l2:

     print(i,"*",j,"=",i*j)
# Out:
# 1 * 1 = 1
# 1 * 2 = 2
# 1 * 3 = 3
# 1 * 4 = 4
# 1 * 5 = 5
# 1 * 6 = 6
# 1 * 7 = 7
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 6 * 1 = 6
# 6 * 2 = 12
# 6 * 3 = 18
# 6 * 4 = 24
# 6 * 5 = 30
# 6 * 6 = 36
# 6 * 7 = 42
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
