# %%
## non mutalble data structure 
# tuple 

tup1=tuple()

type(tup1)
# Out:
# tuple

# %%
tup1=(1,2,3,4,5,6,6)

print (tup1)
# Out:
# (1, 2, 3, 4, 5, 6, 6)

# %%
tup1=([1,2,3,3,4,5])

print(tup1[1:5])
# Out:
# [2, 3, 3, 4]

# %%
print(tup1[::-1])
# Out:
# [5, 4, 3, 3, 2, 1]

# %%
print(tup1.count(3))
# Out:
# 2

# %%
print(tup1.index(2))
# Out:
# 1

# %%
print(tup1[0])
# Out:
# 1

# %%
tup1[0]=5

# %%
tup1[0]
# Out:
# 5

# %%
tup2=("apple",1,"banana",5.555)

# %%
print(tup2)
# Out:
# ('apple', 1, 'banana', 5.555)

# %%
## we cant assign to the index once the tuple is create 

tup2[0]="elve"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 ## we cant assign to the index once the tuple is create
# ----> 3 tup2[0]="elve"
#
# TypeError: 'tuple' object does not support item assignment
