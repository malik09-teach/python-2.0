# %%
## non mutalble data structure 
# tuple 

tup1=tuple()

type(tup1)
# Out:
# tuple

# %%
tup1=(1,2,3,4,5,6,6)

print (tup1)
# Out:
# (1, 2, 3, 4, 5, 6, 6)

# %%
tup1=([1,2,3,3,4,5])

print(tup1[1:5])
# Out:
# [2, 3, 3, 4]

# %%
print(tup1[::-1])
# Out:
# [5, 4, 3, 3, 2, 1]

# %%
print(tup1.count(3))
# Out:
# 2

# %%
print(tup1.index(2))
# Out:
# 1
